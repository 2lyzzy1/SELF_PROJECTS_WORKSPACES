# %% [markdown]
# ### Q-learning

# %%
import gymnasium as gym
env = gym.make('Taxi-v3', render_mode='ansi')
env.reset()
print(env.render())
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
from collections import defaultdic
