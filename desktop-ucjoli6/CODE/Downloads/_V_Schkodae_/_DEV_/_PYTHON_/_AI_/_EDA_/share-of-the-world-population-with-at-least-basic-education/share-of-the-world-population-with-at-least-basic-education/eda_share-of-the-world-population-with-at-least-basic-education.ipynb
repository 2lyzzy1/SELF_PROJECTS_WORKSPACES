# %% [markdown]
# ### EDA EXPERIMENTATION
#
# - Data used : *`share-of-the-world-population-with-at-least-basic-education.csv`* of ***Seaborn***
# - _
# ___

# %% [markdown]
# #### 1rst STEP : IMPORTATION DES BIBLIOTHÈQUES
# ```sh
# pip install <packages_name>
# ```

# %%
# import machine_learning as ml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# #### 2nd STEP : IMPORTATION DES DONNÉES

# %%
df = pd.read_csv("share-of-the-world-population-with-at-least-basic-education.csv")
# "~/Downloads/_V_Schkodae/_Datasets_/"

# %%
df
# Out:
#         Entity  ... Share of population with at least some basic education
# 0    Argentina  ...                                          85.788380
# 1    Argentina  ...                                          87.568400
# 2    Argentina  ...                                          89.140770
# 3    Argentina  ...                                          90.622856
# 4    Argentina  ...                                          91.968285
# ..         ...  ...                                                ...
# 810      World  ...                                          96.876990
# 811      World  ...                                          97.290700
# 812      World  ...                                          97.645546
# 813      World  ...                                          97.948670
# 814      World  ...                                          98.207664
#
# [815 rows x 5 columns]

# %% [markdown]
# ---

# %% [markdown]
# #### 3rd STEP : INFORMATIONS SUR LES DONNÉES DU DATASET

# %%
# print(f"Dataset shape: {df.shape} (rows, columns)")

# %% [markdown]
# ```py
# """
# >>> INFORMATIONS STATISTIQUES ET DÉTAILLÉES DES DONNÉES DU DATASETS [les ÉTIQUETTES]
# """
# ```

# %%
df.info()   # detailed informations on dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815 entries, 0 to 814
# Data columns (total 5 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Entity                                                  815 non-null    object
#  1   Code                                                    815 non-null    object
#  2   Year                                                    815 non-null    int64
#  3   Share of population with no education                   815 non-null    float64
#  4   Share of population with at least some basic education  815 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 32.0+ KB

# %% [markdown]
# **Sumerize**:
# - We have two features (Entity, Code) of type string (Dtype: object);
# - One feature (Year) with integer data (Dtype: int64);
# - Two features (Share of population with no education, Share of population with at least some basic education) armed of float (Dtype: float64);

# %% [markdown]
# ```py
# """
# >>> STATISTIQUE DESCRIPTIVE SUR LES DONNÉES NUMÉRIQUES
# """
# ```

# %%
df.describe().round(2)   # data descrirtions
# Out:
#           Year  ...  Share of population with at least some basic education
# count   815.00  ...                                             815.00
# mean   2023.57  ...                                              90.41
# std      46.65  ...                                              17.99
# min    1820.00  ...                                              11.89
# 25%    1985.00  ...                                              91.29
# 50%    2025.00  ...                                              98.92
# 75%    2065.00  ...                                              99.89
# max    2100.00  ...                                             100.00
#
# [8 rows x 3 columns]

# %% [markdown]
# ___

# %% [markdown]
# #### 4th STEP : DÉTECTION DES VALEURS POUVANT AFFECTER LA QUALITÉ DE L'ANALYSE ET PAR SUITE DU MODÈLE

# %% [markdown]
# ##### Catégorie A : Valeurs Manquantes
# ```
# >>>
# ```

# %%
print(f"Missing values:\n{'='*72}")
df.isna().head()
# Out:
# Missing values:
# ...
#    Entity  ...  Share of population with at least some basic education
# 0   False  ...                                              False
# 1   False  ...                                              False
# 2   False  ...                                              False
# 3   False  ...                                              False
# 4   False  ...                                              False
#
# [5 rows x 5 columns]

# %%
print(df["Code"].get([i for i in range(0,815,216)]))
print(f"\t Missing values count:\n{'='*72}\n{df.isna().sum()}")
# Out:
# 0      ARG
# 216    FRA
# 432    MEX
# 648    SWE
# Name: Code, dtype: object
# 	 Missing values count:
# ...
# Entity                                                    0
# Code                                                      0
# Year                                                      0
# Share of population with no education                     0
# Share of population with at least some basic education    0
# dtype: int64

# %% [markdown]
# ##### Catégorie B : Valeurs Dupliqées
# ```
# >>>
# ```

# %%
print(df.duplicated())
f"Count Of duplicated values: {int(f"{df.duplicated().sum()}")}"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 810    False
# 811    False
# 812    False
# 813    False
# 814    False
# Length: 815, dtype: bool
# 'Count Of duplicated values: 0'

# %%
df[df.duplicated()]
# .sort_values(by=list(df.columns))
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Year, Share of population with no education, Share of population with at least some basic education]
# Index: []

# %% [markdown]
# ##### Catégorie C : Valeurs Aberrantes [ OUTLIERS ]
# ```py
# """
# >>> IQR methods
# """
# ```

# %% [markdown]
# ___

# %% [markdown]
# ### >>> No Missing & Duplicated values

# %%
df
# Out:
#         Entity  ... Share of population with at least some basic education
# 0    Argentina  ...                                          85.788380
# 1    Argentina  ...                                          87.568400
# 2    Argentina  ...                                          89.140770
# 3    Argentina  ...                                          90.622856
# 4    Argentina  ...                                          91.968285
# ..         ...  ...                                                ...
# 810      World  ...                                          96.876990
# 811      World  ...                                          97.290700
# 812      World  ...                                          97.645546
# 813      World  ...                                          97.948670
# 814      World  ...                                          98.207664
#
# [815 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# %%
df.plot()
# Out:
# <Axes: >

# %%
sns.pairplot(df, hue="Entity", kind="hist")

# %% [markdown]
# ---

# %%
encoder = LabelEncoder()

# %%
# Encoding Values
df_encd = encoder.fit_transform(df[''])
df_encd

# %%
X = df.drop("", axis=1)
X

# %%
y = df[""]
y

# %% [markdown]
# #

# %% [markdown]
# ___

# %% [markdown]
# sns.pairplot(df[2:3],x_vars='Code')
# df[2:3]

# %%
penguins = sns.load_dataset("penguins")
sns.pairplot(penguins)

# %%
penguins.plot()
# Out:
# <Axes: >

# %% [markdown]
# ___

# %% [markdown]
# address_book = [{'name':'N.X.', 'addr':'15 Jones St', 'bonus': 70},
#       {'name':'J.P.', 'addr':'1005 5th St', 'bonus': 400},
#       {'name':'A.A.', 'addr':'200001 Bdwy', 'bonus': 5},]
#
# for person in address_book:
#     print(f'{person["name"]:8} || {person["addr"]:20} || {person["bonus"]:>5}')
#
#   # N.X.     || 15 Jones St          ||    70
#   # J.P.     || 1005 5th St          ||   400
#   # A.A.     || 200001 Bdwy          ||     5

# %% [markdown]
# ___

# %% [markdown]
# ```py
# descr = pd.DataFrame({
#     "Chemical_Elements": ['Hydrogen','Manganese','Cesium','Electrum'],
#     "Chemical_Formula": ['H','Mn','Cs','El'],
#     "Atom_counts": [1,5,7,8],
#     "Electron_counts": [1,5,8,4],
# })
# descr
# ```

# %% [markdown]
# #
# ___
# ```py
# import tensorflow as tf
# mnist = tf.keras.datasets.mnist
#
# (x_train, y_train),(x_test, y_test) = mnist.load_data()
# x_train, x_test = x_train / 255.0, x_test / 255.0
#
# model = tf.keras.models.Sequential([
#   tf.keras.layers.Flatten(input_shape=(28, 28)),
#   tf.keras.layers.Dense(128, activation='relu'),
#   tf.keras.layers.Dropout(0.2),
#   tf.keras.layers.Dense(10, activation='softmax')
# ])
#
# model.compile(optimizer='adam',
#   loss='sparse_categorical_crossentropy',
#   metrics=['accuracy'])
#
# model.fit(x_train, y_train, epochs=5)
# model.evaluate(x_test, y_test)
# ```

# %% [markdown]
# ___
